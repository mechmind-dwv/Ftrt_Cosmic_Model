# %% [markdown]
# # 🌞 FTRT Cosmic Model — Pipeline Principal
# Investigación Helio-Biológica y Validación de Mareas Planetarias
#
# ### Propósito
# Ejecutar paso a paso el ciclo completo FTRT: obtención de datos, cálculo y visualización.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Crear carpetas necesarias
os.makedirs('../data/raw', exist_ok=True)
os.makedirs('../data/processed', exist_ok=True)
os.makedirs('../plots', exist_ok=True)

print('✅ Entorno inicializado correctamente.')
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/min/Ftrt_Cosmic_Model/venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/min/Ftrt_Cosmic_Model/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
# ...

# %%
# !python ../scripts/get_noaa_swpc.py
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/home/min/Ftrt_Cosmic_Model/notebooks/../scripts/get_noaa_swpc.py", line 7, in <module>
#     import pandas as pd
#   File "/home/min/Ftrt_Cosmic_Model/venv/lib/python3.12/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/home/min/Ftrt_Cosmic_Model/venv/lib/python3.12/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
# ...

# %%
# !python ../scripts/get_ephem_jpl.py 2003-10-20 2003-11-05
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/home/min/Ftrt_Cosmic_Model/notebooks/../scripts/get_ephem_jpl.py", line 8, in <module>
#     import pandas as pd
#   File "/home/min/Ftrt_Cosmic_Model/venv/lib/python3.12/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/home/min/Ftrt_Cosmic_Model/venv/lib/python3.12/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
# ...

# %%
# !python ../scripts/compute_ftrt.py
# Out:
# FTRT relativo: [1.         0.97201396]

# %%
# !python ../scripts/analyze_compare.py
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/home/min/Ftrt_Cosmic_Model/notebooks/../scripts/analyze_compare.py", line 6, in <module>
#     import pandas as pd
#   File "/home/min/Ftrt_Cosmic_Model/venv/lib/python3.12/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/home/min/Ftrt_Cosmic_Model/venv/lib/python3.12/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
# ...

# %%
df_kp = pd.read_csv('../data/raw/kp_today.csv')
plt.figure(figsize=(10,5))
plt.plot(df_kp['time_tag'], df_kp['kp_index'], label='Kp Index', linewidth=2)
plt.title('Índice Kp Diario')
plt.xlabel('Fecha')
plt.ylabel('Kp')
plt.legend()
plt.grid(True)
plt.show()

print('🌞 Flujo FTRT completado con éxito.')
# Out:
# 🌞 Flujo FTRT completado con éxito.
